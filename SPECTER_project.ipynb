# %% [markdown]
# **The Specter Project**

# %% [markdown]
# **Installing the required libraries**

# %%
# !pip install transformers datasets rich fastlangid wandb
# Out:
# Collecting transformers
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 58.8 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.13.1-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 46.5 MB/s eta 0:00:00
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (13.4.2)
# Collecting fastlangid
#   Downloading fastlangid-1.0.11-py2.py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 77.0 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.15.5-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 95.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 110.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 87.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 26.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich) (2.14.0)
# Collecting fasttext (from fastlangid)
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.4)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.28.1-py2.py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.7/214.7 kB 25.3 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Collecting pybind11>=2.2 (from fasttext->fastlangid)
#   Using cached pybind11-2.11.0-py3-none-any.whl (227 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: fasttext, pathtools
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4479783 sha256=63358528919a158670b157c3f1e5db349d9e600dad9a084c3a2b4d424961adea
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=471ec8a155defb54eb7aa330151ce465c6f1665011f792b6be3a4255bb30db3a
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built fasttext pathtools
# Installing collected packages: tokenizers, safetensors, pathtools, xxhash, smmap, setproctitle, sentry-sdk, pybind11, docker-pycreds, dill, multiprocess, huggingface-hub, gitdb, fasttext, transformers, GitPython, fastlangid, wandb, datasets
# Successfully installed GitPython-3.1.32 datasets-2.13.1 dill-0.3.6 docker-pycreds-0.4.0 fastlangid-1.0.11 fasttext-0.9.2 gitdb-4.0.10 huggingface-hub-0.16.4 multiprocess-0.70.14 pathtools-0.1.2 pybind11-2.11.0 safetensors-0.3.1 sentry-sdk-1.28.1 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.13.3 transformers-4.30.2 wandb-0.15.5 xxhash-3.2.0

# %% [markdown]
# **Mounting google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Changing path to the project repository**

# %%
# %cd /content/drive/MyDrive/Specter-project/MLP_Classification
# Out:
# /content/drive/MyDrive/Specter-project/MLP_Classification

# %% [markdown]
# **Import model and tokenizer**

# %%
from commons.utils import *
from transformers import AutoTokenizer, AutoModel

# load SPECTER pre-trained model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('allenai/specter')
model = AutoModel.from_pretrained('allenai/specter')
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/321 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/222k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %% [markdown]
# **Getting data**

# %%
# !bash commons/getdata.sh
#!gdown --folder https://drive.google.com/drive/folders/14NAz5m6pOUlWq-kf5nGq7LWWSEhJzqOs -O trainedmodels
# Out:
# Retrieving folder list
# Retrieving folder 1AM5sXFHQEFN2Cz3lNoTJq_t_Uvb7mLU4 embeddings
# Retrieving folder 19_WhCqV61DTxJG-GTOx2zu7qi4HwLNdg mag
# Retrieving folder 1xY5IUMjXbod-SPUnYJyPMxQBpz2UTxQ3 mesh
# Retrieving folder 1GMz1szQLgOAl4_HBIvUUtnGtoTKoSUdB mag
# Processing file 1CRQug0SxE61X3cAQkTJrTv6NvMjISk6K test.csv
# Processing file 1Hv3Vde_tDE9auchWYd05cydRMhN3Pg-T train.csv
# Processing file 1R0Vt2f0zXvLOXaM1rxB8kTMgqsaJ7a3t val.csv
# Retrieving folder 1s9awdgXW0Jg0dXqyBtG74BemIZWQEtrJ mesh
# Processing file 1H7uTFOkoA1D59kov9R1lc6dUpHYzChU4 test.csv
# Processing file 1UdSH-FYh31pKZnm92mbQ-QrH1DbKVImE train.csv
# Processing file 1MXLZt3eLdXAywHAOrYeDlGTNqcyk8LSg val.csv
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1CRQug0SxE61X3cAQkTJrTv6NvMjISk6K
# To: /content/drive/MyDrive/Specter-project/MLP_Classification/data/mag/test.csv
# 100% 163k/163k [00:00<00:00, 74.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Hv3Vde_tDE9auchWYd05cydRMhN3Pg-T
# To: /content/drive/MyDrive/Specter-project/MLP_Classification/data/mag/train.csv
# 100% 761k/761k [00:00<00:00, 132MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1R0Vt2f0zXvLOXaM1rxB8kTMgqsaJ7a3t
# To: /content/drive/MyDrive/Specter-project/MLP_Classification/data/mag/val.csv
# 100% 163k/163k [00:00<00:00, 78.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1H7uTFOkoA1D59kov9R1lc6dUpHYzChU4
# To: /content/drive/MyDrive/Specter-project/MLP_Classification/data/mesh/test.csv
# 100% 152k/152k [00:00<00:00, 72.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1UdSH-FYh31pKZnm92mbQ-QrH1DbKVImE
# To: /content/drive/MyDrive/Specter-project/MLP_Classification/data/mesh/train.csv
# 100% 710k/710k [00:00<00:00, 138MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MXLZt3eLdXAywHAOrYeDlGTNqcyk8LSg
# To: /content/drive/MyDrive/Specter-project/MLP_Classification/data/mesh/val.csv
# 100% 152k/152k [00:00<00:00, 91.0MB/s]
# Download completed
# File downloaded successfully.

# %% [markdown]
# **Loading datasets for experiments**

# %%
from commons.data_utils import *
# perform data pre-processing
scidocs = load_metadata()
mag = load_dataset(dataset="mag").join(scidocs, how="inner")
mesh = load_dataset(dataset="mesh").join(scidocs, how="inner")
del scidocs
# Out:
# Retrieving non-english papers: 100%|██████████| 37556/37556 [00:10<00:00, 3691.98it/s]
# Total number of papers in SciDocs: 48473
# Total number of papers after data removing abstract/title lacking papers: 37556
# Total number of papers after data removing non english papers: 37227

# %% [markdown]
# **Data tokenization**

# %%
# takes ~45 seconds
mesh_hf, mag_hf = [
    tokenize_hf(
        hf = to_hf_dataset(dataset=dataset),
        tokenizer=tokenizer
        )
    for dataset in [mesh, mag]
]

# set torch format for the considered data
mesh_hf.set_format("torch")
mag_hf.set_format("torch")
# Out:
# Casting the dataset:   0%|          | 0/23154 [00:00<?, ? examples/s]
# Map:   0%|          | 0/23154 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/14083 [00:00<?, ? examples/s]
# Map:   0%|          | 0/14083 [00:00<?, ? examples/s]

# %% [markdown]
# **Preparing the embeddings**

# %%
from commons.model_utils import embed_data

do_embed=True
if do_embed:
    # embedding takes approximately 30dd mins
    mesh_embeddings = embed_data(model=model, data=mesh_hf.remove_columns("labels"))
    mag_embeddings = embed_data(model=model, data=mag_hf.remove_columns("labels"))
else:
    # alternatively, read embeddings from data
    mesh_embeddings = torch.from_numpy(np.loadtxt("data/embeddings/mesh/mesh_embeddings.txt"))
    mag_embeddings = torch.from_numpy(np.loadtxt("data/embeddings/mag/mag_embeddings.txt"))
# Out:
# Obtaining embeddings: 100%|██████████| 724/724 [12:53<00:00,  1.07s/it]
# Obtaining embeddings: 100%|██████████| 441/441 [07:49<00:00,  1.07s/it]

# %% [markdown]
# **Train-test split**

# %%
# four config dictionaries (one per classification head considered)
from commons.utils import mesh_config_1, mesh_config_2, mesh_config_3, mesh_config_2bis
mesh_splits = mesh_hf.train_test_split(test_size=mesh_config_1["test_size"])

# %% [markdown]
# **Training the model**

# %%
from commons.experiment import Experiment
do_track=False
# instantiate an Experiment, when verbose prints out classification head architecture and number of parameters
ch1 = Experiment(config=mesh_config_1, splits=mesh_splits, dataset=mesh_hf, track=do_track)
# Out:
# Classification head architecture:
# Sequential(
#   (0): Linear(in_features=768, out_features=11, bias=True)
# )
# Number of parameters (MESH model): 1.0995e+08

# %%
from commons.model_utils import embed_data

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Specter-project/MLP_Classification

# %%
train, test = False, True
if train:
    ch1.perform_training()  # might take some time...
else:
    ch1.load_run()

if test: # tests the given configuration
    ch1.test_model()
# Out:
# Model trainedmodels/MESH_CH1.pth loaded successfully!
# 100%|██████████| 73/73 [01:13<00:00,  1.01s/it]
# Average F1-Score 0.9356

# %%
# CH2
ch2 = Experiment(config=mesh_config_2, splits=mesh_splits, dataset=mesh_hf, track=do_track)
if train:
    ch2.perform_training()
else:
    ch2.load_run()
if test:
    ch2.test_model()

# CH3
ch3 = Experiment(config=mesh_config_3, splits=mesh_splits, dataset=mesh_hf, track=do_track)
if train:
    ch3.perform_training()
else:
    ch3.load_run()
if test:
    ch3.test_model()
# Out:
# Classification head architecture:
# Sequential(
#   (0): Linear(in_features=768, out_features=64, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=64, out_features=11, bias=True)
# )
# Number of parameters (MESH model): 1.0999e+08
# Model trainedmodels/MESH_CH2.pth loaded successfully!
# 100%|██████████| 73/73 [01:15<00:00,  1.03s/it]
# Average F1-Score 0.9608
# Classification head architecture:
# Sequential(
#   (0): Linear(in_features=768, out_features=64, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=64, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=64, out_features=64, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=64, out_features=64, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=64, out_features=64, bias=True)
#   (11): ReLU()
#   (12): Linear(in_features=64, out_features=11, bias=True)
# )
# Number of parameters (MESH model): 1.1001e+08
# Model trainedmodels/MESH_CH3.pth loaded successfully!
# 100%|██████████| 73/73 [01:14<00:00,  1.02s/it]
# Average F1-Score 0.0420

# %%
from commons.utils import mag_config_1, mag_config_2, mag_config_3, mag_config_2bis
mag_splits = mag_hf.train_test_split(test_size=mag_config_1["test_size"])

# %%
train, test, do_track = False, True, False

# CH1
ch1 = Experiment(config=mag_config_1, splits=mag_splits, dataset=mag_hf, track=do_track)
if train:
    ch1.perform_training()
else:
    ch1.load_run()
if test:
    ch1.test_model()

# CH2
ch2 = Experiment(config=mag_config_2, splits=mag_splits, dataset=mag_hf, track=do_track)
if train:
    ch2.perform_training()
else:
    ch2.load_run()
if test:
    ch2.test_model()

# CH3
ch3 = Experiment(config=mag_config_3, splits=mag_splits, dataset=mag_hf, track=do_track)
if train:
    ch3.perform_training()
else:
    ch3.load_run()
if test:
    ch3.test_model()
# Out:
# Classification head architecture:
# Sequential(
#   (0): Linear(in_features=768, out_features=19, bias=True)
# )
# Number of parameters (MAG model): 1.0995e+08
# Model trainedmodels/MAG_CH1.pth loaded successfully!
# 100%|██████████| 45/45 [00:47<00:00,  1.06s/it]
# Average F1-Score 0.9448
# Classification head architecture:
# Sequential(
#   (0): Linear(in_features=768, out_features=64, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=64, out_features=19, bias=True)
# )
# Number of parameters (MAG model): 1.0999e+08
# Model trainedmodels/MAG_CH2.pth loaded successfully!
# 100%|██████████| 45/45 [00:46<00:00,  1.03s/it]
# Average F1-Score 0.9379
# Classification head architecture:
# Sequential(
#   (0): Linear(in_features=768, out_features=64, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=64, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=64, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=64, out_features=64, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=64, out_features=64, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=64, out_features=64, bias=True)
#   (11): ReLU()
#   (12): Linear(in_features=64, out_features=19, bias=True)
# )
# Number of parameters (MAG model): 1.1001e+08
# Model trainedmodels/MAG_CH3.pth loaded successfully!
# 100%|██████████| 45/45 [00:43<00:00,  1.03it/s]
# Average F1-Score 0.0105

# %%
# !zip -r /content/file.zip /content/drive/MyDrive/Specter-project
# Out:
# updating: content/drive/MyDrive/Specter-project/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/setup.py (deflated 33%)
# updating: content/drive/MyDrive/Specter-project/README.md (deflated 60%)
# updating: content/drive/MyDrive/Specter-project/Dockerfile.cpu (deflated 43%)
# updating: content/drive/MyDrive/Specter-project/.gitignore (deflated 46%)
# updating: content/drive/MyDrive/Specter-project/requirements.txt (deflated 25%)
# updating: content/drive/MyDrive/Specter-project/Spectroid.pdf (deflated 8%)
# updating: content/drive/MyDrive/Specter-project/LICENSE (deflated 65%)
# updating: content/drive/MyDrive/Specter-project/data/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/sample.ids (deflated 45%)
# updating: content/drive/MyDrive/Specter-project/data/sample-metadata.json (deflated 62%)
# updating: content/drive/MyDrive/Specter-project/data/scibert_scivocab_uncased/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/scibert_scivocab_uncased/scibert.tar.gz (deflated 0%)
# updating: content/drive/MyDrive/Specter-project/data/scibert_scivocab_uncased/vocab.txt (deflated 52%)
# updating: content/drive/MyDrive/Specter-project/data/training/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/training/val.txt (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/training/metadata.json (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/training/test.txt (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/training/train.txt (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/training/data.json (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/vocab/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/vocab/venue.txt (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/vocab/tokens.txt (stored 0%)
# updating: content/drive/MyDrive/Specter-project/data/vocab/non_padded_namespaces.txt (stored 0%)
# updating: content/drive/MyDrive/Specter-project/bash/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/bash/download.sh (deflated 61%)
# updating: content/drive/MyDrive/Specter-project/experiment_configs/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/experiment_configs/simple.jsonnet (deflated 74%)
# updating: content/drive/MyDrive/Specter-project/specter/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/specter/predictor.py (deflated 72%)
# updating: content/drive/MyDrive/Specter-project/specter/data.py (deflated 76%)
# updating: content/drive/MyDrive/Specter-project/specter/model.py (deflated 76%)
# updating: content/drive/MyDrive/Specter-project/specter/__init__.py (deflated 43%)
# updating: content/drive/MyDrive/Specter-project/specter/predict_command.py (deflated 69%)
# updating: content/drive/MyDrive/Specter-project/specter/data_utils/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/specter/data_utils/triplet_sampling_parallel.py (deflated 69%)
# updating: content/drive/MyDrive/Specter-project/specter/data_utils/triplet_sampling.py (deflated 72%)
# updating: content/drive/MyDrive/Specter-project/specter/data_utils/create_training_files.py (deflated 78%)
# updating: content/drive/MyDrive/Specter-project/specter/data_utils/__init__.py (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/Specter_FineTuning.ipynb (deflated 90%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/utils.py (deflated 78%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/__pycache__/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/__pycache__/utils.cpython-310.pyc (deflated 49%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/__pycache__/data_utils.cpython-310.pyc (deflated 52%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/__pycache__/model.cpython-310.pyc (deflated 51%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/__pycache__/model_utils.cpython-310.pyc (deflated 43%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/__pycache__/experiment.cpython-310.pyc (deflated 47%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/data_utils.py (deflated 66%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/getdata.sh (deflated 44%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/model.py (deflated 68%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/model_utils.py (deflated 66%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/commons/experiment.py (deflated 73%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/paper_metadata_mag_mesh.json (deflated 55%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/embeddings/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/embeddings/mag/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/embeddings/mesh/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/mag/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/mag/test.csv (deflated 43%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/mag/train.csv (deflated 43%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/mag/val.csv (deflated 43%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/mesh/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/mesh/val.csv (deflated 43%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/mesh/test.csv (deflated 43%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/data/mesh/train.csv (deflated 43%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/checkpoints/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/trainedmodels/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/trainedmodels/MAG_CH1.pth (deflated 7%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/trainedmodels/MAG_CH2.pth (deflated 7%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/trainedmodels/MAG_CH3.pth (deflated 7%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/trainedmodels/MESH_CH1.pth (deflated 7%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/trainedmodels/MESH_CH2.pth (deflated 7%)
# updating: content/drive/MyDrive/Specter-project/MLP_Classification/trainedmodels/MESH_CH3.pth (deflated 7%)
# updating: content/drive/MyDrive/Specter-project/scripts/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/scripts/embed_papers_hf.py (deflated 63%)
# updating: content/drive/MyDrive/Specter-project/scripts/create_arxiv.py (deflated 68%)
# updating: content/drive/MyDrive/Specter-project/scripts/create_scidocs.py (deflated 72%)
# updating: content/drive/MyDrive/Specter-project/scripts/run-exp-simple.sh (deflated 62%)
# updating: content/drive/MyDrive/Specter-project/scripts/embed.py (deflated 64%)
# updating: content/drive/MyDrive/Specter-project/scripts/pytorch_lightning_training_script/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/scripts/pytorch_lightning_training_script/requirements.txt (deflated 35%)
# updating: content/drive/MyDrive/Specter-project/scripts/pytorch_lightning_training_script/train.py (deflated 76%)
# updating: content/drive/MyDrive/Specter-project/scripts/pytorch_lightning_training_script/README.md (deflated 61%)
# updating: content/drive/MyDrive/Specter-project/scidocs/ (stored 0%)
# updating: content/drive/MyDrive/Specter-project/scidocs/get_scidocs_metrics.py (deflated 61%)
# updating: content/drive/MyDrive/Specter-project/scidocs/classification.py (deflated 62%)
# updating: content/drive/MyDrive/Specter-project/scidocs/run.py (deflated 67%)
